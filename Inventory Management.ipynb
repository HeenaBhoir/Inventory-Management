# %%
grocery={10001:{'Name':'Basmati Rice(1kg)','Price':300,'Expiry date':'August 2022','Quantity':100},
         10002:{'Name':'Peanut butter(100gm)','Price':120,'Expiry date':'December 2021','Quantity':50},
         10003:{'Name':'Bread(1packet)','Price':20,'Expiry date':'September 2021','Quantity':80},
         10004:{'Name':'Fresh Peppers(100gm)','Price':100,'Expiry date':'January 2023','Quantity':60},
         10005:{'Name':'Amul Milk(1bottle)','Price':80,'Expiry date':'September 2021','Quantity':300},
         10006:{'Name':'Pasta(1packet)','Price':35,'Expiry date':'August 2022','Quantity':49},
         10007:{'Name':'Tata Salt(1packet)','Price':75,'Expiry date':'March 2024','Quantity':200},
         10008:{'Name':'Bru Coffee(100gm)','Price':55,'Expiry date':'December 2022','Quantity':65},
         10009:{'Name':'sugar(1kg)','Price':40,'Expiry date':'May 2024','Quantity':490},
         100010:{'Name':'Baby food(1packet)','Price':200,'Expiry date':'November 2021','Quantity':240},
         100011:{'Name':'Vegetable oil(1lit)','Price':380,'Expiry date':'March  2025','Quantity':537},
         100012:{'Name':'Colgate toothpaste(200gm)','Price':150,'Expiry date':'June 2023','Quantity':300},
         100013:{'Name':'Amul cheese(1packet)','Price':250,'Expiry date':'May 2022','Quantity':400},
         100014:{'Name':'Olive oil(1bottle)','Price':300,'Expiry date':'November 2023','Quantity':80},
         100015:{'Name':'Shaving cream(100gm)','Price':245,'Expiry date':'July 2022','Quantity':330},
         100016:{'Name':'Dish soap(1packet)','Price':20,'Expiry date':'May 2023','Quantity':500},
         100017:{'Name':'Baking powder(1packet)','Price':50,'Expiry date':'June 2022','Quantity':100},
         100018:{'Name':'Cocoa Powder(1packet)','Price':70,'Expiry date':'December 2023','Quantity':270},
         100019:{'Name':'Rin Detergent(1packet)','Price':120,'Expiry date':'August 2024','Quantity':400},
         100020:{'Name':'Sour cream(100gm)','Price':100,'Expiry date':'February 2022','Quantity':90},
         100021:{'Name':'Potato chips(1kg)','Price':200,'Expiry date':'November 2021','Quantity':100},
         100022:{'Name':'Dettol Handwash(1packet)','Price':80,'Expiry date':'January 2024','Quantity':340},
         100023:{'Name':'Wheat Flour(1kg)','Price':90,'Expiry date':'November 2022','Quantity':500},
         100024:{'Name':'Corn Starch(1kg)','Price':75,'Expiry date':'September 2023','Quantity':100},
         100025:{'Name':'Masala Oats(1packet)','Price':30,'Expiry date':'March 2023','Quantity':60},
         100026:{'Name':'Choco Chips(1packet)','Price':50,'Expiry date':'December 2022','Quantity':265},
         100027:{'Name':'Cookies(1packet)','Price':180,'Expiry date':'November 2021','Quantity':250},
         100028:{'Name':'Dishwash Liquid(100gm)','Price':130,'Expiry date':'July  2024','Quantity':60},
         100029:{'Name':'Mix Fruit Juice(1lit)','Price':350,'Expiry date':'February 2022','Quantity':155},
         100030:{'Name':'Mustard seeds(100gm)','Price':150,'Expiry date':'May 2022','Quantity':160}}

# %%
 grocery
# Out:
# {10001: {'Name': 'Basmati Rice(1kg)',
#   'Price': 300,
#   'Expiry date': 'August 2022',
#   'Quantity': 100},
#  10002: {'Name': 'Peanut butter(100gm)',
#   'Price': 120,
#   'Expiry date': 'December 2021',
#   'Quantity': 50},
#  10003: {'Name': 'Bread(1packet)',
#   'Price': 20,
#   'Expiry date': 'September 2021',
#   'Quantity': 80},
#  10004: {'Name': 'Fresh Peppers(100gm)',
#   'Price': 100,
#   'Expiry date': 'January 2023',
#   'Quantity': 60},
#  10005: {'Name': 'Amul Milk(1bottle)',
#   'Price': 80,
#   'Expiry date': 'September 2021',
#   'Quantity': 300},
#  10006: {'Name': 'Pasta(1packet)',
#   'Price': 35,
#   'Expiry date': 'August 2022',
#   'Quantity': 49},
#  10007: {'Name': 'Tata Salt(1packet)',
#   'Price': 75,
#   'Expiry date': 'March 2024',
#   'Quantity': 200},
#  10008: {'Name': 'Bru Coffee(100gm)',
#   'Price': 55,
#   'Expiry date': 'December 2022',
#   'Quantity': 65},
#  10009: {'Name': 'sugar(1kg)',
#   'Price': 40,
#   'Expiry date': 'May 2024',
# ...

# %%
import json

# %%
js = json.dumps(grocery)

# %%
js
# Out:
# '{"10001": {"Name": "Basmati Rice(1kg)", "Price": 300, "Expiry date": "August 2022", "Quantity": 100}, "10002": {"Name": "Peanut butter(100gm)", "Price": 120, "Expiry date": "December 2021", "Quantity": 50}, "10003": {"Name": "Bread(1packet)", "Price": 20, "Expiry date": "September 2021", "Quantity": 80}, "10004": {"Name": "Fresh Peppers(100gm)", "Price": 100, "Expiry date": "January 2023", "Quantity": 60}, "10005": {"Name": "Amul Milk(1bottle)", "Price": 80, "Expiry date": "September 2021", "Quantity": 300}, "10006": {"Name": "Pasta(1packet)", "Price": 35, "Expiry date": "August 2022", "Quantity": 49}, "10007": {"Name": "Tata Salt(1packet)", "Price": 75, "Expiry date": "March 2024", "Quantity": 200}, "10008": {"Name": "Bru Coffee(100gm)", "Price": 55, "Expiry date": "December 2022", "Quantity": 65}, "10009": {"Name": "sugar(1kg)", "Price": 40, "Expiry date": "May 2024", "Quantity": 490}, "100010": {"Name": "Baby food(1packet)", "Price": 200, "Expiry date": "November 2021", "Quantity
# ...

# %%
grocery
# Out:
# {10001: {'Name': 'Basmati Rice(1kg)',
#   'Price': 300,
#   'Expiry date': 'August 2022',
#   'Quantity': 100},
#  10002: {'Name': 'Peanut butter(100gm)',
#   'Price': 120,
#   'Expiry date': 'December 2021',
#   'Quantity': 50},
#  10003: {'Name': 'Bread(1packet)',
#   'Price': 20,
#   'Expiry date': 'September 2021',
#   'Quantity': 80},
#  10004: {'Name': 'Fresh Peppers(100gm)',
#   'Price': 100,
#   'Expiry date': 'January 2023',
#   'Quantity': 60},
#  10005: {'Name': 'Amul Milk(1bottle)',
#   'Price': 80,
#   'Expiry date': 'September 2021',
#   'Quantity': 300},
#  10006: {'Name': 'Pasta(1packet)',
#   'Price': 35,
#   'Expiry date': 'August 2022',
#   'Quantity': 49},
#  10007: {'Name': 'Tata Salt(1packet)',
#   'Price': 75,
#   'Expiry date': 'March 2024',
#   'Quantity': 200},
#  10008: {'Name': 'Bru Coffee(100gm)',
#   'Price': 55,
#   'Expiry date': 'December 2022',
#   'Quantity': 65},
#  10009: {'Name': 'sugar(1kg)',
#   'Price': 40,
#   'Expiry date': 'May 2024',
# ...

# %%
fd = open("grocery.json",'w')
fd.write(js)
fd.close()

# %%
fd = open("grocery.json",'r')
          
fd.read()
fd.close()

# %%
grocery
# Out:
# {10001: {'Name': 'Basmati Rice(1kg)',
#   'Price': 300,
#   'Expiry date': 'August 2022',
#   'Quantity': 100},
#  10002: {'Name': 'Peanut butter(100gm)',
#   'Price': 120,
#   'Expiry date': 'December 2021',
#   'Quantity': 50},
#  10003: {'Name': 'Bread(1packet)',
#   'Price': 20,
#   'Expiry date': 'September 2021',
#   'Quantity': 80},
#  10004: {'Name': 'Fresh Peppers(100gm)',
#   'Price': 100,
#   'Expiry date': 'January 2023',
#   'Quantity': 60},
#  10005: {'Name': 'Amul Milk(1bottle)',
#   'Price': 80,
#   'Expiry date': 'September 2021',
#   'Quantity': 300},
#  10006: {'Name': 'Pasta(1packet)',
#   'Price': 35,
#   'Expiry date': 'August 2022',
#   'Quantity': 49},
#  10007: {'Name': 'Tata Salt(1packet)',
#   'Price': 75,
#   'Expiry date': 'March 2024',
#   'Quantity': 200},
#  10008: {'Name': 'Bru Coffee(100gm)',
#   'Price': 55,
#   'Expiry date': 'December 2022',
#   'Quantity': 65},
#  10009: {'Name': 'sugar(1kg)',
#   'Price': 40,
#   'Expiry date': 'May 2024',
# ...

# %% [markdown]
# # New items added into Inventory

# %%
#grocery = json.loads(grocery)

# %%
prod_id = int(input("Enter product id:"))
name = str(input("Enter Name:"))
pr = int(input("Enter Price:"))
ex = str(input("Enter Expiry date:"))
qn = int(input("Enter Quantity:"))

grocery[prod_id] = {'Name': name, 'Price': pr, 'Expiry date': ex, 'Quantity': qn}1
# Out:
# Enter product id:100031
# Enter Name:Bath Soap
# Enter Price:40
# Enter Expiry date:June 2022
# Enter Quantity:380

# %%
grocery
# Out:
# {10001: {'Name': 'Basmati Rice(1kg)',
#   'Price': 300,
#   'Expiry date': 'August 2022',
#   'Quantity': 100},
#  10002: {'Name': 'Peanut butter(100gm)',
#   'Price': 120,
#   'Expiry date': 'December 2021',
#   'Quantity': 50},
#  10003: {'Name': 'Bread(1packet)',
#   'Price': 20,
#   'Expiry date': 'September 2021',
#   'Quantity': 80},
#  10004: {'Name': 'Fresh Peppers(100gm)',
#   'Price': 100,
#   'Expiry date': 'January 2023',
#   'Quantity': 60},
#  10005: {'Name': 'Amul Milk(1bottle)',
#   'Price': 80,
#   'Expiry date': 'September 2021',
#   'Quantity': 300},
#  10006: {'Name': 'Pasta(1packet)',
#   'Price': 35,
#   'Expiry date': 'August 2022',
#   'Quantity': 49},
#  10007: {'Name': 'Tata Salt(1packet)',
#   'Price': 75,
#   'Expiry date': 'March 2024',
#   'Quantity': 200},
#  10008: {'Name': 'Bru Coffee(100gm)',
#   'Price': 55,
#   'Expiry date': 'December 2022',
#   'Quantity': 65},
#  10009: {'Name': 'sugar(1kg)',
#   'Price': 40,
#   'Expiry date': 'May 2024',
# ...

# %%
prod_id = int(input("Enter product id:"))
name = str(input("Enter Name:"))
pr = int(input("Enter Price:"))
ex = str(input("Enter Expiry date:"))
qn = int(input("Enter Quantity:"))

grocery[prod_id] = {'Name': name, 'Price': pr, 'Expiry date': ex, 'Quantity': qn}
# Out:
# Enter product id:100032
# Enter Name:Shampoo
# Enter Price:200
# Enter Expiry date:December 2023
# Enter Quantity:400

# %%
grocery
# Out:
# {10001: {'Name': 'Basmati Rice(1kg)',
#   'Price': 300,
#   'Expiry date': 'August 2022',
#   'Quantity': 100},
#  10002: {'Name': 'Peanut butter(100gm)',
#   'Price': 120,
#   'Expiry date': 'December 2021',
#   'Quantity': 50},
#  10003: {'Name': 'Bread(1packet)',
#   'Price': 20,
#   'Expiry date': 'September 2021',
#   'Quantity': 80},
#  10004: {'Name': 'Fresh Peppers(100gm)',
#   'Price': 100,
#   'Expiry date': 'January 2023',
#   'Quantity': 60},
#  10005: {'Name': 'Amul Milk(1bottle)',
#   'Price': 80,
#   'Expiry date': 'September 2021',
#   'Quantity': 300},
#  10006: {'Name': 'Pasta(1packet)',
#   'Price': 35,
#   'Expiry date': 'August 2022',
#   'Quantity': 49},
#  10007: {'Name': 'Tata Salt(1packet)',
#   'Price': 75,
#   'Expiry date': 'March 2024',
#   'Quantity': 200},
#  10008: {'Name': 'Bru Coffee(100gm)',
#   'Price': 55,
#   'Expiry date': 'December 2022',
#   'Quantity': 65},
#  10009: {'Name': 'sugar(1kg)',
#   'Price': 40,
#   'Expiry date': 'May 2024',
# ...

# %%
js = json.dumps(grocery)

# %%
fd = open("new_items.json",'w')
fd.write(js)
fd.close()

# %% [markdown]
# # purchase

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("_______________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant
sales = {1 : {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}}
# Out:
# Enter the product_id:100022
# Enter the Quantity:15
# ************************
# Product:  Dettol Handwash(1packet)
# Price:  80
# Billing Amount:  1200
# _______________________________

# %%
grocery
# Out:
# {10001: {'Name': 'Basmati Rice(1kg)',
#   'Price': 300,
#   'Expiry date': 'August 2022',
#   'Quantity': 100},
#  10002: {'Name': 'Peanut butter(100gm)',
#   'Price': 120,
#   'Expiry date': 'December 2021',
#   'Quantity': 50},
#  10003: {'Name': 'Bread(1packet)',
#   'Price': 20,
#   'Expiry date': 'September 2021',
#   'Quantity': 80},
#  10004: {'Name': 'Fresh Peppers(100gm)',
#   'Price': 100,
#   'Expiry date': 'January 2023',
#   'Quantity': 60},
#  10005: {'Name': 'Amul Milk(1bottle)',
#   'Price': 80,
#   'Expiry date': 'September 2021',
#   'Quantity': 300},
#  10006: {'Name': 'Pasta(1packet)',
#   'Price': 35,
#   'Expiry date': 'August 2022',
#   'Quantity': 49},
#  10007: {'Name': 'Tata Salt(1packet)',
#   'Price': 75,
#   'Expiry date': 'March 2024',
#   'Quantity': 200},
#  10008: {'Name': 'Bru Coffee(100gm)',
#   'Price': 55,
#   'Expiry date': 'December 2022',
#   'Quantity': 65},
#  10009: {'Name': 'sugar(1kg)',
#   'Price': 40,
#   'Expiry date': 'May 2024',
# ...

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("__________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:10006
# Enter the Quantity:18
# ****************************
# Product:  Pasta(1packet)
# Price:  35
# Billing Amount:  630
# __________________________________

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:100029
# Enter the Quantity:1
# ****************************
# Product:  Mix Fruit Juice(1lit)
# Price:  350
# Billing Amount:  350
# ________________________________

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("******************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("_______________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:100017
# Enter the Quantity:20
# ******************************
# Product:  Baking powder(1packet)
# Price:  50
# Billing Amount:  1000
# _______________________________________

# %%
grocery
# Out:
# {10001: {'Name': 'Basmati Rice(1kg)',
#   'Price': 300,
#   'Expiry date': 'August 2022',
#   'Quantity': 100},
#  10002: {'Name': 'Peanut butter(100gm)',
#   'Price': 120,
#   'Expiry date': 'December 2021',
#   'Quantity': 50},
#  10003: {'Name': 'Bread(1packet)',
#   'Price': 20,
#   'Expiry date': 'September 2021',
#   'Quantity': 80},
#  10004: {'Name': 'Fresh Peppers(100gm)',
#   'Price': 100,
#   'Expiry date': 'January 2023',
#   'Quantity': 60},
#  10005: {'Name': 'Amul Milk(1bottle)',
#   'Price': 80,
#   'Expiry date': 'September 2021',
#   'Quantity': 300},
#  10006: {'Name': 'Pasta(1packet)',
#   'Price': 35,
#   'Expiry date': 'August 2022',
#   'Quantity': 31},
#  10007: {'Name': 'Tata Salt(1packet)',
#   'Price': 75,
#   'Expiry date': 'March 2024',
#   'Quantity': 200},
#  10008: {'Name': 'Bru Coffee(100gm)',
#   'Price': 55,
#   'Expiry date': 'December 2022',
#   'Quantity': 65},
#  10009: {'Name': 'sugar(1kg)',
#   'Price': 40,
#   'Expiry date': 'May 2024',
# ...

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("__________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:10001
# Enter the Quantity:10
# ****************************
# Product:  Basmati Rice(1kg)
# Price:  300
# Billing Amount:  3000
# __________________________________

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("__________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:100032
# Enter the Quantity:22
# ****************************
# Product:  Shampoo
# Price:  200
# Billing Amount:  4400
# __________________________________

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("__________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:100030
# Enter the Quantity:2
# ****************************
# Product:  Mustard seeds(100gm)
# Price:  150
# Billing Amount:  300
# __________________________________

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("__________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:100015
# Enter the Quantity:5
# ****************************
# Product:  Shaving cream(100gm)
# Price:  245
# Billing Amount:  1225
# __________________________________

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("__________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:100010
# Enter the Quantity:10
# ****************************
# Product:  Baby food(1packet)
# Price:  200
# Billing Amount:  2000
# __________________________________

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("__________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:10008
# Enter the Quantity:1
# ****************************
# Product:  Bru Coffee(100gm)
# Price:  55
# Billing Amount:  55
# __________________________________

# %%
ui_prod = int(input("Enter the product_id:"))
ui_quant = int(input("Enter the Quantity:"))
print("****************************")
print("Product: ",grocery[ui_prod]['Name'])
print("Price: ",grocery[ui_prod]['Price'])
print("Billing Amount: ",grocery[ui_prod]['Price'] * ui_quant)


print("__________________________________")
grocery[ui_prod]['Quantity'] = grocery[ui_prod]['Quantity'] - ui_quant

sales[len(sales) + 1] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount' : grocery[ui_prod]['Price']*ui_quant}
# Out:
# Enter the product_id:100025
# Enter the Quantity:5
# ****************************
# Product:  Masala Oats(1packet)
# Price:  30
# Billing Amount:  150
# __________________________________

# %%
js = json.dumps(grocery)

# %% [markdown]
# # Update Inventory after Purchase

# %%
fd = open("purchase.json",'w')
fd.write(js)
fd.close()

# %% [markdown]
# # Sales JSON

# %%
sales
# Out:
# {1: {'prod': 100022, 'qn': 15, 'amount': 1200},
#  2: {'prod': 10006, 'qn': 18, 'amount': 630},
#  3: {'prod': 100029, 'qn': 1, 'amount': 350},
#  4: {'prod': 100017, 'qn': 20, 'amount': 1000},
#  5: {'prod': 10001, 'qn': 10, 'amount': 3000},
#  6: {'prod': 100032, 'qn': 22, 'amount': 4400},
#  7: {'prod': 100030, 'qn': 2, 'amount': 300},
#  8: {'prod': 100015, 'qn': 5, 'amount': 1225},
#  9: {'prod': 100010, 'qn': 10, 'amount': 2000},
#  10: {'prod': 10008, 'qn': 1, 'amount': 55},
#  11: {'prod': 100025, 'qn': 5, 'amount': 150}}

# %%
js = json.dumps(sales)

# %%
fd = open("sales.json",'w')
fd.write(js)
fd.close()
